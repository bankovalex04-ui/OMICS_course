# %% [markdown]
# # Project 3 — ChIP-seq analysis
#
# ## Goal
#
# The goal of this project was to process ChIP-seq data for chromatin marks/factors and identify enrichment peaks relative to input.
#
# Processed samples:
#
# - MoPh7_H3K9me3
# - MoPh7_H3K27Ac
# - MoPh7_H2A119Ub
# - MoPh7_CTCF
# - input control

# %% [markdown]
# ## Workflow summary
#
# The workflow included:
#
# 1. Downloading raw ChIP-seq reads.
# 2. Adapter trimming.
# 3. BWA alignment.
# 4. MAPQ filtering.
# 5. bigWig track generation.
# 6. MACS3 peak calling.
# 7. Fold-enrichment track generation.
# 8. IGV visualization.

# %%
# Full ChIP-seq pipeline
cd day3_ChIPseq_practice
THREADS=3 bash scripts/run_all_chipseq_pipeline.sh

# %% [markdown]
# ## Output files
#
# The pipeline generated:
#
# - q30 bigWig tracks
# - input bigWig track
# - MACS3 peak files
# - fold-enrichment bigWig tracks
# - summit BED files for narrow peaks

# %% [markdown]
# ## Selected example locus
#
# Example CTCF locus:
#
# `chr20:33,443,000–33,453,000`
#
# The selected CTCF peak was one of the strongest peaks by signal value:
#
# `chr20:33447326–33449351`
#
# ## Interpretation
#
# The CTCF ChIP-seq signal is strongly enriched relative to input.
# MACS3 identifies a narrow peak in this region, and the summit marks the point of maximum enrichment.
#
# This is consistent with a local CTCF binding site.
