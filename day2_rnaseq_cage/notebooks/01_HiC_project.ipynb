# %% [markdown]
# # Project 1 — Hi-C analysis
#
# ## Goal
#
# The goal of this project was to process Hi-C data and compare contact maps between four samples: MoPh7, MoPh11, MoPh14, and MoPh15.
#
# MoPh7 was used as a reference/control sample for visual comparison.

# %% [markdown]
# ## Workflow summary
#
# The main workflow included:
#
# 1. Processing paired-end Hi-C reads.
# 2. Building `.hic` files.
# 3. Opening contact maps in Juicebox.
# 4. Comparing whole-genome and chromosome-level contact patterns.

# %%
# Example checks used during the project
# find . -name "*.hic"
# ls -lh results/

# %% [markdown]
# ## Result
#
# Whole-genome Hi-C maps showed the expected strong diagonal signal in all samples.
# No clear large off-diagonal interchromosomal blocks were observed.
#
# ## Biological interpretation
#
# The result suggests that there are no obvious large-scale interchromosomal rearrangements visible in these Hi-C maps relative to MoPh7.
#
# ## Limitations
#
# The maps are relatively sparse, so subtle structures such as TADs, loops, or small rearrangements cannot be interpreted reliably without deeper coverage and additional statistical analysis.
